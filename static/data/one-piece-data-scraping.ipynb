# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
URL = "https://www.sportskeeda.com/anime/how-many-devil-fruits-one-piece-all-205-fruits-listed"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-us">
# <head>
# <script>
# var gtmFired = false;
# document.addEventListener("mousemove", function() { loadGTM(); });
# document.addEventListener("scroll", function() { loadGTM(); });
# function loadGTM() {
# if(gtmFired) {
# return;
# }
# gtmFired = true;
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PZMZ8RP');
# }
# </script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="index, follow, max-image-preview:large" name="robots"/>
# <meta content="en-us" http-equiv="content-language"/>
# ...

# %%
results = soup.find(class_="content-holder")

# %%
print(results.prettify())
# Out:
# <div class="content-holder">
#  <div class="feed-header">
#  </div>
#  <style>
#   .auth-wall-parent {
# display: flex;
# align-items: center;
# justify-content: space-around;
# background: rgba(255, 255, 255, 0.74);
# border-radius: 10px;
# border-style: solid;
# border-color: #999999;
# border-width: 1px;
# width: auto;
# height: auto;
# position: relative;
# backdrop-filter: blur(10.5px);
# padding: 20px;
# font-family: 'Poppins', -apple-system, BlinkMacSystemFont, "Segoe UI", "Liberation Sans", sans-serif;
# }
# .auth-wall-parent .wall-message-container {
# display: flex;
# flex-direction: column;
# align-items: center;
# gap: 5px;
# }
# .auth-wall-parent .wall-lock-image {
# background: none;
# margin: 0;
# }
# .auth-wall-parent .reading-like-message {
# color: #474747;
# text-align: center;
# font-weight: 400;
# font-size: 14px;
# }
# .auth-wall-parent .reading-login-message {
# color: #474747;
# font-size: 16px;
# font-style: normal;
# font-weight: 600;
# line-height: normal;
# ...

# %%
list_elements = results.find_all("li")
print(list_elements)
# Out:
# [<li><strong>Arms-Arms Fruit - </strong>Allows users to transform their bodies into weapons of any kind. User: Baby 5.</li>, <li><strong>Art-Art Fruit -</strong> Allows users to transform people and objects into abstract art. User: Giolla.</li>, <li><strong>Barrier-Barrier Fruit -</strong> Allows users to create unbreakable barriers. Users: Semimaru (past), Bartolomeo (current).</li>, <li><strong>Berry-Berry Fruit - </strong>Allows users to split their bodies into separate spheres. User: Very Good.</li>, <li><strong>Bind-Bind Fruit - </strong>Allows users to create iron cages to bind their enemies. User: Hina.</li>, <li><strong>Bis-Bis Fruit -</strong> Allows users to generate and manipulate biscuits. User: Charlotte Cracker.</li>, <li><strong>Boing-Boing Fruit -</strong> Allows users to turn their limbs into springs. User: Bellamy.</li>, <li><strong>Book-Book Fruit -</strong> Allows users to trap people inside books. User: Charlotte Mont-d'Or.</li>, <li><strong>Boom-Boom Fruit -</st
# ...

# %%
df = pd.DataFrame(columns=["Fruit", "Ability Description", "Name", "Fruit Type"])
rows = []

for list_element in list_elements:
    list_splits = list_element.text.split(" - ")
    fruit = list_splits[0]
    ability = list_splits[1].split(" User: ")[0]
    user = list_splits[1].split(": ")[1] if len(list_splits[1].split(": ")) > 1 else None
    
    rows.append({"Fruit": fruit, "Ability Description": ability, "Name": user})
    
df = pd.concat([df, pd.DataFrame(rows)], ignore_index=True)

# %%
df['Name'] = df['Name'].str.strip(".")

# %%
df['Fruit Type'][0:88] = 'Paramecia'
df['Fruit Type'][88:152] = 'Zoan'
df['Fruit Type'][152:164] = 'Logia'
df['Fruit Type'][164:] = 'Non-Canon Fruit'

# %%
df.loc[164:]
# Out:
#                                      Fruit  \
# 164                      Clank-Clank Fruit
# 165                      Chain-Chain Fruit
# 166                      Color-Color Fruit
# 167                        Copy-Copy Fruit
# 168                        Cube-Cube Fruit
# 169                    Fondly-Fondly Fruit
# 170                        Gold-Gold Fruit
# 171                        Grow-Grow Fruit
# 172                        Hard-Hard Fruit
# 173                          Hot-Hot Fruit
# 174                      Knead-Knead Fruit
# 175                      Lucky-Lucky Fruit
# 176                        Mini-Mini Fruit
# 177                        More-More Fruit
# 178                          Net-Net Fruit
# 179                      Nitro-Nitro Fruit
# 180                          Pet-Pet Fruit
# 181                    Return-Return Fruit
# 182                        Roll-Roll Fruit
# 183                    Scream-Scream Fruit
# 184                    Sickle-Sickle Fruit
# ...

# %%
# bounty data scraping
URL2 = "https://onepiece.fandom.com/wiki/Bounties/List"
page2 = requests.get(URL2)

soup2 = BeautifulSoup(page2.content, "html.parser")
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Bounties | One Piece Wiki | Fandom</title>
# ...

# %%
dfs = pd.read_html(URL2)

# %%
dfs
# Out:
# [                                                 Name  \
#  0                                     Monkey D. Luffy
#  1   First Bounty: At the end of the Arlong Park Ar...
#  2                                        Roronoa Zoro
#  3   First Bounty: The swordsman of the Straw Hat P...
#  4                                                Nami
#  5   First Bounty: After the Enies Lobby Arc and fo...
#  6                                           God Usopp
#  7   First Bounty: Following the events at Enies Lo...
#  8                                               Sanji
#  9   First Bounty: Because of the events at Enies L...
#  10                                  Tony Tony Chopper
#  11  First Bounty: After the events at Enies Lobby,...
#  12                                         Nico Robin
#  13  First Bounty: Robin has a 79,000,000 bounty fr...
#  14                                             Franky
#  15  First Bounty: For burning the Pluton blueprint...
# ...

# %%
dfs[34]
# Out:
#      Rank              Name         Nickname      Bounty          Affiliation  \
# 0     1.0      Gol D. Roger      Pirate King  5564800000        Roger Pirates
# 1     2.0    Edward Newgate       Whitebeard  5046000000   Whitebeard Pirates
# 2     3.0            Kaidou    of the Beasts  4611100000       Beasts Pirates
# 3     4.0  Charlotte Linlin          Big Mom  4388000000      Big Mom Pirates
# 4     5.0            Shanks         Red Hair  4048900000     Red Hair Pirates
# ..    ...               ...              ...         ...                  ...
# 162   NaN             Shiki  The Golden Lion           ?  Golden Lion Pirates
# 163   NaN            Shiryu      of the Rain           ?   Blackbeard Pirates
# 164   NaN              Zeff          Red Leg           ?         Cook Pirates
# 165   NaN  Charlotte Amande       Demon Lady           ?      Big Mom Pirates
# 166   NaN    Rocks D. Xebec              NaN           ?        Rocks Pirates
#
#        Status
# 0    Inactive
# ...

# %%
df3 = pd.DataFrame(columns=["Name", "Bounty", "Affiliation", "Status"])

df3['Name'] = dfs[34]['Name']
df3['Bounty'] = dfs[34]['Bounty']
df3['Affiliation'] = dfs[34]['Affiliation']
df3['Status'] = dfs[34]['Status']

print(df3.to_string())
# Out:
#                        Name                Bounty                      Affiliation    Status
# 0              Gol D. Roger            5564800000                    Roger Pirates  Inactive
# 1            Edward Newgate            5046000000               Whitebeard Pirates  Inactive
# 2                    Kaidou            4611100000                   Beasts Pirates    Active
# 3          Charlotte Linlin            4388000000                  Big Mom Pirates    Active
# 4                    Shanks            4048900000                 Red Hair Pirates    Active
# 5         Marshall D. Teach            3996000000               Blackbeard Pirates    Active
# 6            Dracule Mihawk            3590000000                      Cross Guild    Active
# 7                     Buggy            3189000000                      Cross Guild    Active
# 8           Monkey D. Luffy            3000000000                Straw Hat Pirates    Active
# ...

# %%
final = pd.merge(df, df3, how="left", on='Name')
final['Ability Description'] = final['Ability Description'].apply(lambda x: f'"{x}"')
final.fillna(value="Unknown", inplace=True)
print(final.head())
# Out:
#                    Fruit                                Ability Description  \
# 0        Arms-Arms Fruit  "Allows users to transform their bodies into w...
# 1          Art-Art Fruit  "Allows users to transform people and objects ...
# 2  Barrier-Barrier Fruit  "Allows users to create unbreakable barriers. ...
# 3      Berry-Berry Fruit  "Allows users to split their bodies into separ...
# 4        Bind-Bind Fruit  "Allows users to create iron cages to bind the...
#
#                                     Name Fruit Type   Bounty Affiliation  \
# 0                                 Baby 5  Paramecia  Unknown     Unknown
# 1                                 Giolla  Paramecia  Unknown     Unknown
# 2  Semimaru (past), Bartolomeo (current)  Paramecia  Unknown     Unknown
# 3                              Very Good  Paramecia  Unknown     Unknown
# 4                                   Hina  Paramecia  Unknown     Unknown
#
#     Status
# 0  Unknown
# 1  Unknown
# 2  Unknown
# 3  Unknown
# ...

# %%
final[~final['Bounty'].str.contains("Unknown")]
# Out:
#                                                Fruit  \
# 5                                      Bis-Bis Fruit
# 6                                  Boing-Boing Fruit
# 7                                    Book-Book Fruit
# 8                                    Boom-Boom Fruit
# 15                                   Chop-Chop Fruit
# 22                                 Float-Float Fruit
# 23                               Flower-Flower Fruit
# 27                                   Heat-Heat Fruit
# 31                               Jacket-Jacket Fruit
# 32                                   Kilo-Kilo Fruit
# 33                                   Lick-Lick Fruit
# 34                                   Love-Love Fruit
# 35                               Magnet-Magnet Fruit
# 40                                 Mochi-Mochi Fruit
# 43                                     Paw-Paw Fruit
# 46                                     Pop-Pop Fruit
# 48                                   Puff-Puff Fruit
# ...

# %%
# final.to_csv('/Users/stephaniedang/Documents/GitHub/op-project/devil-fruit-users.csv', index=False)
